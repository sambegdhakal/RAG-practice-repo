# %%
from qdrant_client import models, QdrantClient
from sentence_transformers import SentenceTransformer
from typing import Union

# %%
import pandas as pd
df = pd.read_csv('commentary_2025_ENG.1.csv')
data = df.to_dict('records')

# %%
import pandas as pd

for col in df.columns:
    if df[col].dtype == 'object':  #if string or mixed data type
        # converting to date time
        converted_col=pd.to_datetime(df[col], errors='coerce', format='%Y-%m-%d %H:%M:%S')
        
        # check if most of the rows are valid date time or not
        if converted_col.notna().sum() > len(df) * 0.5:
            df[col] = converted_col.fillna(pd.Timestamp('1900-01-01')) #if valid assigned a default value
        else:
            df[col] = df[col].fillna('no values')

    elif pd.api.types.is_numeric_dtype(df[col]):  # if Numeric columns seen then value as 0
        df[col] = df[col].fillna(0)

    elif pd.api.types.is_datetime64_any_dtype(df[col]):  # if its a data type then a default value
        df[col] = df[col].fillna(pd.Timestamp('1900-01-01'))

# %%
encoder = SentenceTransformer('all-MiniLM-L6-v2')

# %%
qdrant = QdrantClient(":memory:")

# %%
collection_name = "commentary"

#if collection already exists delete it
if qdrant.collection_exists(collection_name=collection_name):
    qdrant.delete_collection(collection_name=collection_name)

# %%
#after deletion if exists create collection
qdrant.create_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(
        size=encoder.get_sentence_embedding_dimension(),
        distance=models.Distance.COSINE
    )
)

import time
time.sleep(100)

# %%
# vectorization and points
qdrant.upload_points(
    collection_name=collection_name,
    points=[
        models.PointStruct(
            id=idx,
            vector=encoder.encode(doc["commentaryText"]).tolist(),
            payload=doc,
        ) for idx, doc in enumerate(data) # data is the variable holding all the wines
    ]
)

# %%
user_prompt = "penalty missed" #providing some user prompt

# %%
import pprint
# query encoded to vectors
query_vector = encoder.encode(user_prompt).tolist()


# Perform the search / query
response =  qdrant.query_points(
    collection_name=collection_name,
    query=query_vector,
    limit=10,
    with_payload=True
)

for hit in response.points:
    print(hit.payload, "score:", hit.score)

# holding the search results
search_results = [hit.payload for hit in response.points]
# Out:
# {'seasonType': 13481, 'eventId': 740612, 'commentaryOrder': 39, 'playId': 45749168, 'clockDisplayValue': "38'", 'commentaryText': 'Penalty missed. Bruno Fernandes (Manchester United) right footed shot is too high.', 'updateDateTime': '2025-08-25 04:57:58'} score: 0.729119944542675
# {'seasonType': 13481, 'eventId': 740649, 'commentaryOrder': 68, 'playId': 45987368, 'clockDisplayValue': "76'", 'commentaryText': 'Penalty saved. Bruno Fernandes (Manchester United) right footed shot saved in the bottom right corner by Caoimhín Kelleher (Brentford).', 'updateDateTime': '2025-09-28 05:17:47'} score: 0.645788672417261
# {'seasonType': 13481, 'eventId': 740623, 'commentaryOrder': 51, 'playId': 45792530, 'clockDisplayValue': "59'", 'commentaryText': 'Penalty saved. Kevin Schade (Brentford) right footed shot saved in the bottom left corner by Robin Roefs (Sunderland).', 'updateDateTime': '2025-08-31 05:08:09'} score: 0.6335756659559626
# {'seasonType': 13481, 'eventId': 740598, 'commentaryOrder': 2, 'playId': 45662889, 'clockDisplayValue': "2'", 'commentaryText': 'Attempt missed. Raúl Jiménez (Fulham) left footed shot from the left side of the box misses to the left. Assisted by Alex Iwobi.', 'updateDateTime': '2025-08-17 04:58:39'} score: 0.6299013870259206
# {'seasonType': 13481, 'eventId': 740611, 'commentaryOrder': 75, 'playId': 45747772, 'clockDisplayValue': "77'", 'commentaryText': 'Penalty saved. Danny Welbeck (Brighton and Hove Albion) right footed shot saved in the bottom right corner by Jordan Pickford (Everton).', 'updateDateTime': '2025-08-24 18:10:13'} score: 0.6289811877026568
# {'seasonType': 13481, 'eventId': 740650, 'commentaryOrder': 93, 'playId': 46009477, 'clockDisplayValue': "82'", 'commentaryText': 'Attempt missed. Samuel Chukwueze (Fulham) left footed shot from the centre of the box misses to the left.', 'updateDateTime': '2025-09-29 05:23:55'} score: 0.6198201963143841
# {'seasonType': 13481, 'eventId': 740629, 'commentaryOrder': 13, 'playId': 45868829, 'clockDisplayValue': "11'", 'commentaryText': 'Attempt missed. Rodrigo Gomes (Wolverhampton Wanderers) right footed shot from the left side of the box misses to the left. Assisted by Ladislav Krejcí.', 'updateDateTime': '2025-09-14 05:28:00'} score: 0.6155160653432539
# {'seasonType': 13481, 'eventId': 740679, 'commentaryOrder': 108, 'playId': 46237676, 'clockDisplayValue': "90'+11'", 'commentaryText': 'Attempt missed. Joe Gomez (Liverpool) right footed shot from the centre of the box misses to the left.', 'updateDateTime': '2025-10-26 05:23:25'} score: 0.6153846760279102
# {'seasonType': 13481, 'eventId': 740642, 'commentaryOrder': 11, 'playId': 45931677, 'clockDisplayValue': "16'", 'commentaryText': 'Attempt missed. Joachim Andersen (Fulham) header from very close range misses to the right. Assisted by Sasa Lukic with a cross following a corner.', 'updateDateTime': '2025-09-20 20:39:12'} score: 0.6146249724534261
# {'seasonType': 13481, 'eventId': 740598, 'commentaryOrder': 53, 'playId': 45664995, 'clockDisplayValue': "48'", 'commentaryText': 'Attempt missed. Raúl Jiménez (Fulham) right footed shot from the left side of the six yard box is close, but misses to the left.', 'updateDateTime': '2025-08-17 04:58:39'} score: 0.6140829934542467

# %%
import os
from dotenv import load_dotenv

# Load .env file
load_dotenv()

api_key = os.getenv("GROQ_API_KEY")

# %%
import pprint
from groq import Groq


user_prompt = "Penalty Missed" #prompt from user


query_vector = encoder.encode(user_prompt).tolist() #encoding user prompt

#semantic search in quadrant
response = qdrant.query_points(
    collection_name=collection_name,
    query=query_vector,
    limit=10,
    with_payload=True
)

# stored search reuslts
search_results = [hit.payload for hit in response.points]


#using groq; s
client = Groq()

completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",  #8 b model
    messages=[
        {
            "role": "system",
            "content": (
                "You are a helpful assistant"
            )
        },
        {"role": "user", "content": "What is Deep Learning?"},
    ]
)

print("\n--- Groq Model Response ---")
print(completion.choices[0].message.content)
# Out:
# --- Groq Model Response ---
# Deep learning is a subfield of machine learning that focuses on the use of artificial neural networks with multiple layers to analyze and interpret data. These neural networks are called "deep" because they have many layers, typically more than two, which allow them to learn and represent complex patterns and relationships in data.
#
# Deep learning models are inspired by the structure and function of the human brain, with each layer processing different aspects of the input data. The first layer of the network processes basic features, such as edges and lines, while subsequent layers combine these features to form more complex representations, such as objects and scenes.
#
# Deep learning has been highly successful in a variety of applications, including:
#
# 1. **Computer Vision**: Deep learning has led to significant advancements in image and video recognition, object detection, and segmentation.
# 2. **Natural Language Processing (NLP)**: Deep learning has improved language understanding, sentiment analysis, text classification, and machine translation.
# 3. **Speech Recognition**: Deep learning has enhanced speech recognition, with applications in voice assistants, voice-to-text, and language translation.
# 4. **Robotics**: Deep learning has enabled robots to recognize and interact with their environment, perform tasks, and learn from experience.
# 5. **Predictive Modeling**: Deep learning has improved predictive modeling in various domains, including healthcare, finance, and climate modeling.
#
# Some of the key characteristics of deep learning include:
#
# 1. **Neural Network Architecture**: Deep learning models are based on artificial neural networks with multiple layers.
# 2. **Backpropagation**: A process of minimizing the error between predicted and actual outputs through iterative adjustments to the model's parameters.
# 3. **Activation Functions**: Used to introduce non-linearity in the model, allowing it to learn complex relationships between inputs and outputs.
# 4. **Batch Normalization**: A technique to normalize the inputs to each layer, improving the stability and performance of the model.
# 5. **Regularization**: Techniques used to prevent overfitting and improve the model's generalization capabilities.
#
# Deep learning has many benefits, including:
#
# 1. **Improved Accuracy**: Deep learning models can achieve high accuracy in various tasks, especially when large amounts of data are available.
# 2. **Auto-feature Extraction**: Deep learning models can automatically extract relevant features from data, reducing the need for manual feature engineering.
# 3. **Flexibility**: Deep learning models can be designed to perform a variety of tasks, including classification, regression, and generation.
#
# However, deep learning also has some challenges, including:
#
# 1. **Training Time**: Deep learning models can require extensive computational resources and time to train, especially for large datasets.
# 2. **Overfitting**: Deep learning models can suffer from overfitting, where they become too complex and fail to generalize well to new data.
# 3. **Interpretability**: Deep learning models can be difficult to interpret, making it challenging to understand why a particular prediction was made.
#
# Overall, deep learning is a powerful tool for analyzing and interpreting complex data, and its applications are vast and growing.

# %%
import pprint
import json
from groq import Groq

user_prompt = "Penalty Missed" #prompt from user


query_vector = encoder.encode(user_prompt).tolist() #encoding user prompt

#semantic search in quadrant
response = qdrant.query_points(
    collection_name=collection_name,
    query=query_vector,
    limit=10,
    with_payload=True
)

# stored search reuslts
search_results = [hit.payload for hit in response.points]
context_text = "\n".join([
    json.dumps(item, ensure_ascii=False, default=str) for item in search_results
])
context_text = context_text.encode("utf-8", errors="ignore").decode()

#using groq; s
client = Groq()

# Chat completion
completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {
            "role": "system",
            "content": (
                "You are a helpful assistant and soccer statistics specialist. "
                "Your top priority is to help the user analyze soccer stats, "
                "summarize insights, and answer queries accurately."
            )
        },
        {
            "role": "user",
            "content": (
                f"The user asked: {user_prompt}\n\n"
                f"Here are related results from the database:\n{context_text}\n\n"
                "Please summarize or analyze the relevant information."
            )
        },
    ]
)

print("\n--- Groq Model Response ---")
print(completion.choices[0].message.content)
# Out:
# --- Groq Model Response ---
# Based on the provided data, we can identify the relevant information related to "Penalty Missed." Here's a summary:
#
# 1. **Number of Penalties Missed**: In the given data, there are no records of penalties actually being missed, but there are two records of penalties being attempted but not scored (saved) and other shots missing the target.
#
# 2. **Penalties Saved**: There are two instances where penalties were saved:
#     - **Bruno Fernandes (Manchester United)**: Saved by Caoimhín Kelleher (Brentford) in the bottom right corner.
#     - **Danny Welbeck (Brighton and Hove Albion)**: Saved by Jordan Pickford (Everton) in the bottom right corner.
#     - **Kevin Schade (Brentford)**: Saved by Robin Roefs (Sunderland) in the bottom left corner.
#
# 3. **Other Shots Missed**: Five instances of shots missing the target:
#     - **Raúl Jiménez (Fulham)** has two instances, including one from the left side of the box and one from close range.
#     - **Samuel Chukwueze (Fulham)**: Shot from the centre of the box missed to the left.
#     - **Rodrigo Gomes (Wolverhampton Wanderers)**: Right footed shot from the left side of the box missed to the left.
#     - **Joe Gomez (Liverpool)**: Right footed shot from the centre of the box missed to the left.
#     - **Joachim Andersen (Fulham)**: Header from very close range missed to the right.
#
# Let me know if there's anything else I can help you with.
